# %% [markdown]
# # Курс Введение в обработку естественного языка / Практическое задание урока 6. Классификация текста

# %% [markdown]
# ## Задание
# Взять ноутбук colab_text_classification_part1.ipynb который разбирали на занятии и добавить пункты которые мы пропустили
#
# 1. Посмотрите на токены если будут мусорные добавьте их в стоп слова и обучите заново
#
# 2. Проверьте повысилось ли качество на стандартных подходах при лемматизации/и без неё
#
# 3. Удалите/(замените на тег) из текстов сущности (имена, локации, что-то ещё). Запустите классификатор и модельки на сеточках
#
# 4. Сделайте выводы

# %% [markdown]
# # Решение
# Мои изменения/добавления в коде ноутбука отмечены тегом # to do

# %%
# !wget -O imdb.zip -qq --no-check-certificate "https://drive.google.com/uc?export=download&id=1vrQ5czMHoO3pEnmofFskymXMkq_u1dPc"
# !unzip imdb.zip
# !pip -q install eli5
# !pip -q install spacy
# !python -m spacy download en
# Out:
# Archive:  imdb.zip
#   inflating: test.tsv
#   inflating: train.tsv
#      |████████████████████████████████| 106 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 12.0 MB 5.3 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %% [markdown]
# Тут придется авторизировать запрос к гугл драйву, извините.

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id': '1d1-5FwxK53ePwygNWeG7jhsOWZbi5HOv'})
downloaded.GetContentFile('train_docs.pkl')

downloaded = drive.CreateFile({'id': '1MMOY477t965G0C5DtXeREVp0X85UaNq5'})
downloaded.GetContentFile('test_docs.pkl')
# Out:
# WARNING:googleapiclient.discovery_cache:file_cache is unavailable when using oauth2client >= 4.0.0 or google-auth
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 33, in <module>
#     from oauth2client.contrib.locked_file import LockedFile
# ModuleNotFoundError: No module named 'oauth2client.contrib.locked_file'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 37, in <module>
#     from oauth2client.locked_file import LockedFile
# ModuleNotFoundError: No module named 'oauth2client.locked_file'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/googleapiclient/discovery_cache/__init__.py", line 44, in autodetect
# ...

# %% [markdown]
# # Классификация текстов
#
# Начнём с самого простого - анализа тональности текста.
#
# Будем классифицировать отзывы с IMDB на положительные/отрицательные.
#
# Датасет взят с http://ai.stanford.edu/~amaas/data/sentiment/

# %%
# !head train.tsv
# Out:
# is_positive	review
# ...

# %%
import pandas as pd

train_df = pd.read_csv("train.tsv", delimiter="\t")
test_df = pd.read_csv("test.tsv", delimiter="\t")

print('Train size = {}'.format(len(train_df)))
print('Test size = {}'.format(len(test_df)))
# Out:
# Train size = 25000
# Test size = 25000

# %% [markdown]
# Посмотрите глазами на тексты? Какие есть зацепки, как определить, что это за сентимент?
#
# Самое простое, как всегда - найти ключевые слова.

# %%
#@title Начинаем классифицировать! { vertical-output: true, display-mode: "form" }
positive_words = 'love', 'great', 'best', 'wonderful' #@param {type:"raw"}
negative_words = 'worst', 'awful', '1/10', 'crap' #@param {type:"raw"}

positives_count = test_df.review.apply(lambda text: sum(word in text for word in positive_words))
negatives_count = test_df.review.apply(lambda text: sum(word in text for word in negative_words))
is_positive = positives_count > negatives_count
correct_count = (is_positive == test_df.is_positive).values.sum()

accuracy = correct_count / len(test_df)

print('Test accuracy = {:.2%}'.format(accuracy))
if accuracy > 0.71:
    from IPython.display import Image, display
    display(Image('https://s3.amazonaws.com/achgen360/t/rmmoZsub.png', width=500))
# Out:
# Test accuracy = 66.73%

# %% [markdown]
# **Задание** Придумайте хорошие ключевые слова или фразы и наберите хотя бы 71% точности на тесте (и не забудьте посмотреть на код классификации!)

# %%
# to do Увеличим размерность вывода на экран столбцов датасета
pd.set_option('display.max_colwidth', 150)

# %%
# to do Выводим на экран несколько строк датасета для визуального исследования
train_df.loc[train_df['is_positive'] == 1][1000:1010]
# Out:
#       is_positive                                                                                                                                                 review
# 1975            1  I remember seeing this movie shown several years ago on the Lifetime TV network and thought it was an interesting story. Several years later I see...
# 1977            1  I never trust the opinions of anyone regarding a film. That goes for critics as well. Sure, if it gets positive reviews that's OK and a plus, but ...
# 1981            1  The movie was very moving. It was tender, and funny at the same time. The scenery was absolutely beautiful! Peter Faulk and Paul Reiser gave award...
# 1985            1  Let's keep it simple: My two kids were glued to this movie. It has its flaws from an adult perspective, but buy some jelly-worms and just enjoy it...
# ...

# %% [markdown]
# # to do  В следующей ячейке добавлены ключевые слова и набрано 71.07% точности на тест

# %%
#@title Начинаем классифицировать! { vertical-output: true, display-mode: "form" }
positive_words = 'love', 'great', 'best',  'wonderful', 'favorite',  'refreshing', 'wonderfully', 'excellent', 'highly', 'favourite', 'amazing', 'enjoy', 'OK', #@param {type:"raw"}
negative_words = 'worst', 'awful', '1/10', 'crap', 'disappointment', 'waste', 'poorly', 'lacks', 'mess', 'laughable', 'fails', 'avoid' #@param {type:"raw"}

positives_count = test_df.review.apply(lambda text: sum(word in text for word in positive_words))
negatives_count = test_df.review.apply(lambda text: sum(word in text for word in negative_words))
is_positive = positives_count > negatives_count
correct_count = (is_positive == test_df.is_positive).values.sum()

accuracy = correct_count / len(test_df)

print('Test accuracy = {:.2%}'.format(accuracy))
if accuracy > 0.71:
    from IPython.display import Image, display
    display(Image('https://s3.amazonaws.com/achgen360/t/rmmoZsub.png', width=500))
# Out:
# Test accuracy = 71.07%
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py:364: FormatterWarning: image/png formatter returned invalid type <class 'tuple'> (expected (<class 'bytes'>, <class 'str'>)) for object: <IPython.core.display.Image object>
#   FormatterWarning

# %% [markdown]
# **Задание** Кому-нибудь нравятся эти `<br /><br />`? Лично мне - нет. Напишите регулярку, которая будет их удалять

# %%
import re

pattern = re.compile('<br />')

print(train_df['review'].iloc[3])
print(pattern.subn(' ', train_df['review'].iloc[3])[0])
# Out:
# Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...<br /><br />THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".<br /><br />THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.<br /><br />THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it on
# ...

# %% [markdown]
# Применим ее:

# %%
train_df['review'] = train_df['review'].apply(lambda text: pattern.subn(' ', text)[0])
test_df['review'] = test_df['review'].apply(lambda text: pattern.subn(' ', text)[0])

# %% [markdown]
# Пора переходить к машинке!
#
# Как будем представлять текст? Проще всего - мешком слов.
#
# Заведём большой-большой словарь - список всех слов в обучающей выборке. Тогда каждое предложение можно представить в виде вектора, в котором будет записано, сколько раз встретилось каждое из возможных слов:
#
# ![bow](https://raw.githubusercontent.com/DanAnastasyev/DeepNLP-Course/master/Week%2001/Images/BOW.png)
#
# Простой и приятный способ сделать это - запихнуть тексты в `CountVectorizer`.
#
# Он имеет такую сигнатуру:
#
# ```python
# CountVectorizer(input='content', encoding='utf-8', decode_error='strict', strip_accents=None, lowercase=True, preprocessor=None, tokenizer=None, stop_words=None, token_pattern=r'(?u)\b\w\w+\b', ngram_range=(1, 1), analyzer='word', max_df=1.0, min_df=1, max_features=None, vocabulary=None, binary=False, dtype=<class ‘numpy.int64'>)
# ```
#
# Для начала обратим внимание на параметры `lowercase=True` и `max_df=1.0, min_df=1, max_features=None` - они про то, что по умолчанию все слова будут приводиться к нижнему регистру и в словарь попадут все слова, встречавшиеся в текстах.
#
# При желании можно было бы убрать слишком редкие или слишком частотные слова - пока не будем этого делать.
#
# Посмотрим на простом примере, как он будет работать:

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

dummy_data = ['The movie was excellent',
              'the movie was awful']

dummy_matrix = vectorizer.fit_transform(dummy_data)

print(dummy_matrix.toarray())
print(vectorizer.get_feature_names())
# Out:
# [[0 1 1 1 1]
#  [1 0 1 1 1]]
# ['awful', 'excellent', 'movie', 'the', 'was']

# %% [markdown]
# *Как именно vectorizer определяет границы слов? Обратите внимание на параметр `token_pattern=r'(?u)\b\w\w+\b'` - как он будет работать?*
#
# Запустим его на реальных данных:

# %%
# to do Мой лист стоп-слов будет содержать как 'english' стоп-слова,
# так и избранные мной стоп-слова
from sklearn.feature_extraction import text

my_stop_words = text.ENGLISH_STOP_WORDS.union(['00',
 '000',
 '0000000000001',
 '00001',
 '00015',
 '000s',
 '001',
 '003830',
 '006',
 '007',
 '0079',
 '0080',
 '0083',
 '0093638',
 '00am',
 '00pm',
 '00s',
 '01',
 '01pm',
 '02',
 '020410',
 '029',
 '03',
 '04',
 '041',
 '05',
 '050',
 '06',
 '06th',
 '07',
 '08',
 '087',
 '089',
 '08th',
 '09',
 '0f',
 '0ne',
 '0r',
 '0s',
 '10',
 '100',
 '1000',
 '1000000',
 '10000000000000',
 '1000lb',
 '1000s',
 '1001',
 '100b',
 '100k',
 '100m',
 '100min',
 '100mph',
 '100s',
 '100th',
 '100x',
 '100yards',
 '101',
 '101st',
 '102',
 '102nd',
 '103',
 '104',
 '1040',
 '1040a',
 '1040s',
 '105',
 '1050',
 '105lbs',
 '106',
 '106min',
 '107',
 '108',
 '109',
 '10am',
 '10lines',
 '10mil',
 '10min',
 '10minutes',
 '10p',
 '10pm',
 '10s',
 '10star',
 '10th',
 '10x',
 '10yr',
 '11',
 '110',
 '1100',
 '11001001',
 '1100ad',
 '111',
 '112',
 '1138',
 '114',
 '1146',
 '115',
 '116',
 '117',
 '11f',
 '11m',
 '11th',
 '12',
 '120',
 '1200',
 '1200f',
 '1201',
 '1202',
 '123',
 '12383499143743701',
 '125',
 '125m',
 '127',
 '128',
 '12a',
 '12hr',
 '12m',
 '12mm',
 '12s',
 '12th',
 '13',
 '130',
 '1300',
 '1300s',
 '131',
 '1318',
 '132',
 '134',
 '135',
 '135m',
 '136',
 '137',
 '138',
 '139',
 '13k',
 '13s',
 '13th',
 '14',
 '140',
 '1408',
 '140hp',
 '1415',
 '142',
 '145',
 '1454',
 '146',
 '147',
 '1473',
 '149',
 '1492',
 '14a',
 '14ieme',
 '14s',
 '14th',
 '14yr',
 '14ème',
 '15',
 '150',
 '1500',
 '1500s',
 '150_worst_cases_of_nepotism',
 '150k',
 '150m',
 '151',
 '152',
 '153',
 '1547',
 '155',
 '156',
 '1561',
 '157',
 '158',
 '1594',
 '15mins',
 '15minutes',
 '15s',
 '15th',
 '16',
 '160',
 '1600',
 '1600s',
 '160lbs',
 '161',
 '1610',
 '163',
 '164',
 '165',
 '166',
 '1660s',
 '168',
 '169',
 '1692',
 '16ieme',
 '16k',
 '16mm',
 '16s',
 '16th',
 '16x9',
 '16ème',
 '16éme',
 '17',
 '170',
 '1700',
 '1700s',
 '1701',
 '171',
 '175',
 '177',
 '1775',
 '1780s',
 '1790s',
 '1794',
 '1798',
 '17million',
 '17th',
 '18',
 '180',
 '1800',
 '1800mph',
 '1800s',
 '1801',
 '1805',
 '1809',
 '180d',
 '1812',
 '1813',
 '18137',
 '1814',
 '1816',
 '1820',
 '1824',
 '183',
 '1830',
 '1832',
 '1836',
 '1837',
 '1838',
 '1839',
 '1840',
 '1840s',
 '1844',
 '1846',
 '1847',
 '185',
 '1850',
 '1850ies',
 '1850s',
 '1852',
 '1853',
 '1854',
 '1855',
 '1859',
 '1860',
 '1860s',
 '1861',
 '1862',
 '1863',
 '1864',
 '1865',
 '1870',
 '1870s',
 '1871',
 '1873',
 '1874',
 '1875',
 '1876',
 '188',
 '1880',
 '1880s',
 '1881',
 '1886',
 '1887',
 '1888',
 '1889',
 '188o',
 '1890',
 '1890s',
 '1892',
 '1893',
 '1894',
 '1895',
 '1896',
 '1897',
 '1898',
 '1899',
 '18a',
 '18s',
 '18th',
 '18year',
 '19',
 '190',
 '1900',
 '1900s',
 '1901',
 '1902',
 '1903',
 '1904',
 '1905',
 '1906',
 '1907',
 '1908',
 '1909',
 '1910',
 '1910s',
 '1911',
 '1912',
 '1913',
 '1914',
 '1915',
 '1916',
 '1917',
 '1918',
 '1919',
 '192',
 '1920',
 '1920ies',
 '1920s',
 '1921',
 '1922',
 '1923',
 '1924',
 '1925',
 '1926',
 '1927',
 '1928',
 '1929',
 '1930',
 '1930ies',
 '1930s',
 '1931',
 '1932',
 '1933',
 '1934',
 '1935',
 '1936',
 '1937',
 '1938',
 '1939',
 '193o',
 '194',
 '1940',
 '1940s',
 '1941',
 '1942',
 '1943',
 '1944',
 '1945',
 '1946',
 '1947',
 '1948',
 '1949',
 '1949er',
 '195',
 '1950',
 '1950s',
 '1951',
 '1952',
 '1953',
 '1954',
 '1955',
 '1956',
 '1957',
 '1958',
 '1959',
 '1960',
 '1960s',
 '1961',
 '1961s',
 '1962',
 '1963',
 '1964',
 '1965',
 '1966',
 '1967',
 '1968',
 '1969',
 '197',
 '1970',
 '1970ies',
 '1970s',
 '1971',
 '1972',
 '1973',
 '1974',
 '1975',
 '1976',
 '1977',
 '1978',
 '1979',
 '19796',
 '197o',
 '1980',
 '1980ies',
 '1980s',
 '1981',
 '1982',
 '1982s',
 '1983',
 '1983s',
 '1984',
 '1984ish',
 '1985',
 '1986',
 '1987',
 '1988',
 '1989',
 '1990',
 '1990s',
 '1991',
 '1992',
 '1993',
 '1994',
 '1995',
 '1996',
 '1997',
 '1998',
 '1999',
 '19k',
 '19th',
 '19thc',
 '1am',
 '1and',
 '1d',
 '1h',
 '1h30',
 '1h40',
 '1h40m',
 '1h53',
 '1hour',
 '1hr',
 '1million',
 '1min',
 '1mln',
 '1o',
 '1s',
 '1st',
 '1ton',
 '1tv',
 '1½',
 '1ç',
 '20',
 '200',
 '2000',
 '20000',
 '20001',
 '2000ad',
 '2000s',
 '2001',
 '2002',
 '2003',
 '2004',
 '2004s',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '200ft',
 '200th',
 '201',
 '2010',
 '2012',
 '2013',
 '2015',
 '2017',
 '2019',
 '2020',
 '2022',
 '2023',
 '2030',
 '2031',
 '2033',
 '2035',
 '2036',
 '2038',
 '204',
 '2040',
 '2044',
 '2046',
 '2047',
 '2050',
 '2053',
 '2054',
 '206',
 '2060',
 '2070',
 '2080',
 '209',
 '2090',
 '20c',
 '20ft',
 '20k',
 '20m',
 '20mins',
 '20minutes',
 '20mn',
 '20p',
 '20perr',
 '20s',
 '20th',
 '20ties',
 '20widow',
 '20x',
 '20year',
 '20yrs',
 '21',
 '210',
 '2100',
 '214',
 '215',
 '2151',
 '216',
 '21699',
 '21849889',
 '21849890',
 '21849907',
 '21st',
 '22',
 '220',
 '2200',
 '221',
 '2210',
 '22101',
 '222',
 '223',
 '225',
 '2257',
 '225mins',
 '227',
 '22d',
 '22h45',
 '22nd',
 '23',
 '230lbs',
 '230mph',
 '231',
 '232',
 '233',
 '236',
 '237',
 '23d',
 '23rd',
 '24',
 '240',
 '2400',
 '241',
 '242',
 '248',
 '2480',
 '249',
 '24m30s',
 '24th',
 '24years',
 '25',
 '250',
 '2500',
 '250000',
 '25million',
 '25mins',
 '25s',
 '25th',
 '25yo',
 '25yrs',
 '26',
 '260',
 '2600',
 '261k',
 '262',
 '2642',
 '269',
 '26th',
 '27',
 '270',
 '272',
 '273',
 '274',
 '275',
 '2772',
 '278',
 '27th',
 '27x41',
 '28',
 '280',
 '285',
 '28th',
 '29',
 '29th',
 '2am',
 '2d',
 '2fast',
 '2furious',
 '2h',
 '2h30',
 '2hour',
 '2hours',
 '2hr',
 '2hrs',
 '2in',
 '2inch',
 '2k',
 '2more',
 '2nd',
 '2oo4',
 '2oo5',
 '2pac',
 '2point4',
 '2s',
 '2x4',
 '30',
 '300',
 '3000',
 '300ad',
 '300c',
 '300lbs',
 '300mln',
 '3012',
 '303',
 '305',
 '30am',
 '30ish',
 '30k',
 '30lbs',
 '30min',
 '30mins',
 '30pm',
 '30s',
 '30something',
 '30th',
 '30ties',
 '31',
 '3199',
 '31st',
 '32',
 '3200',
 '320x180',
 '32lb',
 '32nd',
 '33',
 '330am',
 '330mins',
 '332960073452',
 '336th',
 '33m',
 '34',
 '345',
 '3462',
 '34th',
 '35',
 '350',
 '3500',
 '3516',
 '356',
 '357',
 '35c',
 '35mins',
 '35mm',
 '35pm',
 '35th',
 '35yr',
 '36',
 '360',
 '365',
 '36th',
 '37',
 '370',
 '372',
 '378',
 '38',
 '38k',
 '38th',
 '39',
 '395',
 '39th',
 '3am',
 '3bs',
 '3d',
 '3dvd',
 '3k',
 '3lbs',
 '3m',
 '3mins',
 '3p',
 '3p0',
 '3pm',
 '3po',
 '3rd',
 '3rds',
 '3th',
 '3who',
 '3x5',
 '3yrs',
 '40',
 '400',
 '4000',
 '401k',
 '405',
 '409',
 '40am',
 '40min',
 '40mins',
 '40mph',
 '40s',
 '40th',
 '41',
 '42',
 '420',
 '425',
 '428',
 '42nd',
 '43',
 '430',
 '44',
 '440',
 '442nd',
 '44c',
 '44yrs',
 '45',
 '450',
 '4500',
 '451',
 '454',
 '45am',
 '45min',
 '45mins',
 '45s',
 '46',
 '465',
 '469',
 '47',
 '475',
 '477',
 '47s',
 '48',
 '480m',
 '480p',
 '48hrs',
 '49',
 '498',
 '49th',
 '4am',
 '4cylinder',
 '4d',
 '4eva',
 '4ever',
 '4f',
 '4h',
 '4hrs',
 '4k',
 '4kids',
 '4m',
 '4o',
 '4pm',
 '4th',
 '4w',
 '4ward',
 '4x',
 '4x4',
 '50',
 '500',
 '5000',
 '500000',
 '500ad',
 '500db',
 '500lbs',
 '502',
 '50c',
 '50ft',
 '50ies',
 '50ish',
 '50k',
 '50min',
 '50mins',
 '50s',
 '50th',
 '50usd',
 '51',
 '51b',
 '51st',
 '52',
 '5200',
 '5250',
 '529',
 '52s',
 '53',
 '53m',
 '54',
 '5400',
 '540i',
 '54th',
 '55',
 '5539',
 '555',
 '55th',
 '56',
 '57',
 '571',
 '576',
 '578',
 '57d',
 '58',
 '58th',
 '59',
 '598947',
 '59th',
 '5hrs',
 '5ive',
 '5kph',
 '5million',
 '5min',
 '5mins',
 '5s',
 '5seconds',
 '5th',
 '5x',
 '5x5',
 '5years',
 '5yo',
 '5yrs',
 '60',
 '600',
 '6000',
 '607',
 '608',
 '60ies',
 '60ish',
 '60mph',
 '60s',
 '60th',
 '60ties',
 '61',
 '618',
 '62',
 '6200',
 '62229249',
 '63',
 '637',
 '63rd',
 '64',
 '65',
 '65m',
 '66',
 '660',
 '666',
 '66er',
 '67',
 '6723',
 '67th',
 '68',
 '68th',
 '69',
 '69th',
 '6am',
 '6b',
 '6ft',
 '6hours',
 '6k',
 '6million',
 '6pm',
 '6th',
 '6wks',
 '6yo',
 '70',
 '700',
 '701',
 '707',
 '70ies',
 '70m',
 '70mm',
 '70s',
 '70th',
 '71',
 '713',
 '72',
 '72nd',
 '73',
 '7300',
 '735',
 '737',
 '74',
 '740',
 '740il',
 '747',
 '747s',
 '74th',
 '75',
 '750',
 '75054',
 '75c',
 '75m',
 '76',
 '7600',
 '77',
 '78',
 '788',
 '78rpm',
 '79',
 '79th',
 '7days',
 '7even',
 '7eventy',
 '7ft',
 '7ish',
 '7mm',
 '7th',
 '7½th',
 '80',
 '800',
 '8000',
 '80ies',
 '80ish',
 '80min',
 '80s',
 '80yr',
 '81',
 '817',
 '819',
 '82',
 '820',
 '8217',
 '8230',
 '83',
 '84',
 '849',
 '84f',
 '84s',
 '85',
 '850',
 '850pm',
 '86',
 '86s',
 '87',
 '8700',
 '8763',
 '878',
 '87minutes',
 '88',
 '88min',
 '89',
 '89or',
 '89s',
 '8bit',
 '8ftdf',
 '8k',
 '8mm',
 '8o',
 '8p',
 '8pm',
 '8star',
 '8th',
 '8u',
 '8½',
 '90',
 '900',
 '9000',
 '90210',
 '905',
 '90c',
 '90ish',
 '90min',
 '90mins',
 '90s',
 '91',
 '911',
 '914',
 '917',
 '92',
 '921',
 '92fs',
 '92nd',
 '93',
 '937',
 '94',
 '9484',
 '94s',
 '94th',
 '95',
 '950',
 '95th',
 '96',
 '97',
 '970',
 '974th',
 '978',
 '98',
 '987',
 '98minutes',
 '99',
 '998',
 '999',
 '9999',
 '99cents',
 '99p',
 '99½',
 '9_',
 '9am',
 '9as',
 '9do',
 '9ers',
 '9is',
 '9lbs',
 '9mm',
 '9of10',
 '9pm',
 '9s',
 '9th',
 '____',
 '_____',
 '______',
 '_________',
 '____________________________________',
 '_____________________________________',
 '__________________________________________________________________',
 ])

# %%
# vectorizer = CountVectorizer() # первоначальный код
vectorizer = CountVectorizer(stop_words=my_stop_words) # to do Добавлены стоп-слова
vectorizer.fit(train_df['review'].values)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None,
#                 stop_words=frozenset({'00', '000', '0000000000001', '00001',
#                                       '00015', '000s', '001', '003830', '006',
#                                       '007', '0079', '0080', '0083', '0093638',
#                                       '00am', '00pm', '00s', '01', '01pm', '02',
#                                       '020410', '029', '03', '04', '041', '05',
#                                       '050', '06', '06th', '07', ...}),
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %% [markdown]
# Посмотрим на слова, попавшие в словарь:

# %%
vectorizer.get_feature_names()
# Out:
# ['_a',
#  '_absolute',
#  '_am_',
#  '_and_',
#  '_angel_',
#  '_annie_',
#  '_any_',
#  '_anything_',
#  '_apocalyptically',
#  '_as',
#  '_atlantis',
#  '_atlantis_',
#  '_attack',
#  '_before_',
#  '_blair',
#  '_both_',
#  '_bounce_',
#  '_by',
#  '_can',
#  '_cannon_',
#  '_certainly_',
#  '_could',
#  '_cruel',
#  '_dirty',
#  '_discuss_',
#  '_discussing_',
#  '_do_',
#  '_dr',
#  '_dying',
#  '_earned_',
#  '_everything_',
#  '_ex_executives',
#  '_extremeley_',
#  '_extremely_',
#  '_film_',
#  '_get_',
#  '_have_',
#  '_i_',
#  '_innerly',
#  '_inside_',
#  '_inspire_',
#  '_is_',
#  '_les',
#  '_love_',
#  '_magic_',
#  '_much_',
#  '_mystery',
#  '_napolean',
#  '_new',
#  '_night',
#  '_not_',
#  '_obviously_',
#  '_other_',
#  '_penetrate_',
#  '_plan',
#  '_possible_',
#  '_real_',
#  '_really_is_',
#  '_shall',
#  '_shock',
#  '_so_',
#  '_so_much_',
#  '_somewhere_',
#  '_spiritited',
#  '_starstruck_',
#  '_strictly',
#  '_sung_',
#  '_the',
#  '_the_',
# ...

# %% [markdown]
# Попробуем кого-нибудь таки сконвертировать

# %%
vectorizer.transform([train_df['review'].iloc[3]])
# Out:
# <1x73527 sparse matrix of type '<class 'numpy.int64'>'
# 	with 135 stored elements in Compressed Sparse Row format>

# %% [markdown]
# То, что и хотели - вектор с bow (т.е. bag-of-words) представлением исходного текста.
#
# И чем эта информация может помочь? Ну, всё тем же - какие-то слова носят положительный окрас, какие-то - отрицательный. Большинство вообще нейтральный, да.
#
# ![bow with weights](https://github.com/DanAnastasyev/DeepNLP-Course/raw/master/Week%2001/Images/BOW_weights.png)
#
# Хочется, наверное, подобрать коэффициенты, которые будут определять уровень окраса, да? Подбирать нужно по обучающей выборке, а не как мы перед этим делали.
#
# Например, для выборки
# ```
# 1   The movie was excellent
# 0   the movie was awful
# ```
# легко подобрать коэффициенты на глазок: что-нибудь вроде `+1` для `excellent`,  `-1` для `awful` и по нулям всем остальным.
#
# Построим линейную модель, которая станет этим заниматься. Она будет учиться строить разделяющую гиперплоскость в пространстве bow-векторов.
#
# Проверим, как справится логистическая регрессия с нашей супер-выборкой из пары предложений

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

dummy_data = ['The movie was excellent',
              'the movie was awful']
dummy_labels = [1, 0]

vectorizer = CountVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(dummy_data, dummy_labels)

print(vectorizer.get_feature_names())
print(classifier.coef_)
# Out:
# ['awful', 'excellent', 'movie', 'the', 'was']
# [[-0.40104279  0.40104279  0.          0.          0.        ]]

# %% [markdown]
# Получилось что надо.
#
# Запустим теперь её на реальных данных.

# %%
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Pipeline(memory=None,
#          steps=[('vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
# ...

# %%
# to do Без стоп-слов и с ними Test accuracy = 86.50%
from sklearn.metrics import accuracy_score

def eval_model(model, test_df):
    preds = model.predict(test_df['review'])
    print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
    
eval_model(model, test_df)
# Out:
# Test accuracy = 86.50%

# %% [markdown]
# Прогресс!
#
# Хочется как-то посмотреть, что заинтересовало классификатор. К счастью, сделать это совсем просто:

# %%
import eli5
eli5.show_weights(classifier, vec=vectorizer, top=40)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
# ...

# %% [markdown]
# Посмотрим на конкретные примеры его работы:

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>18.921</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
# ...

# %%
print('Positive' if test_df['is_positive'].iloc[6] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[6], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Negative
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-10.913</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
# ...

# %% [markdown]
# Посмотрим на примеры неправильной классификации, наконец:

# %%
import numpy as np

preds = model.predict(test_df['review'])
incorrect_pred_index = np.random.choice(np.where(preds != test_df['is_positive'])[0])

eli5.show_prediction(classifier, test_df['review'].iloc[incorrect_pred_index],
                     vec=vectorizer, targets=['positive'], target_names=['negative', 'positive'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.599</b>, score <b>0.402</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
# ...

# %% [markdown]
# ## Придумываем новые признаки

# %% [markdown]
# ### Tf-idf
#
# Сейчас мы на все слова смотрим с одинаковым весом - хотя какие-то из них более редкие, какие-то более частые, и эта частотность - полезная, вообще говоря, информация.
#
# Самый простой способ добавить статистическую информацию о частотностях - сделать *tf-idf* взвешивание:
#
# $$\text{tf-idf}(t, d) = \text{tf}(t, d) \times \text{idf}(t)$$
#
# *tf* - term-frequency - частотность слова `t` в конкретном документе `d` (рецензии в нашем случае). Это ровно то, что мы уже считали.
#
# *idf* - inverse document-frequency - коэффициент, который тем больше, чем в меньшем числе документов встречалось данное слово. Считается как-нибудь так:
# $$\text{idf}(t) = \text{log}\frac{1 + n_d}{1 + n_{d(t)}} + 1$$
# где $n_d$ - число всех документов, а $n_{d(t)}$ - число документов со словом `t`.
#
# Использовать его просто - нужно заменить `CountVectorizer` на `TfidfVectorizer`.
#
# **Задание** Попробуйте запустить `TfidfVectorizer`. Посмотрите на ошибки, которые он научился исправлять, и на ошибки, которые он начал делать - по сравнению с `CountVectorizer`.

# %% [markdown]
# ### to do 1. Эксперименты по увеличению range

# %%
# to do Без стоп-слов Test accuracy = 88.28%. Со стоп-словами Test accuracy = 87.99%
from sklearn.feature_extraction.text import TfidfVectorizer

# vectorizer = TfidfVectorizer() первоначальный код
vectorizer = TfidfVectorizer(stop_words=my_stop_words) # to do Добавлены стоп-слова
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 87.99%

# %% [markdown]
# ### N-граммы слов
#
# До сих пор мы смотрели на тексты как на мешок слов - но очевидно, что есть разница между `good movie` и `not good movie`.
#
# Добавим информацию (хоть какую-то) о последовательностях слов - будем извлекать еще и биграммы слов.
#
# В Vectorizer'ах для этого есть параметр `ngram_range=(n_1, n_2)` - он говорит, что нужны n_1-...n_2-граммы.
#
# **Задание** Попробуйте увеличенный range и поинтерпретируйте полученный результат.

# %% [markdown]
# ### to do Результаты экспериментов по увеличению range:
# * Test accuracy = 88.64% в исходном коде при ngram_range=(1, 2).
# * Test accuracy = 85.88% в случае ngram_range=(2, 4)
# * Test accuracy = 86.89% в случае ngram_range=(1, 4)
#
# Можно предположить, что увеличение range свыше биграмм снижает возможности по распознаванию эмоциональной окраски.

# %%
# исходный код с range (1, 2)
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 88.64%

# %%
# to do изменим range на (2, 4)
vectorizer = TfidfVectorizer(ngram_range=(2, 4))
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 85.88%

# %%
# to do изменим range на (1, 4)
vectorizer = TfidfVectorizer(ngram_range=(1, 4))
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 86.89%

# %% [markdown]
# ### N-граммы символов
#
# Символьные n-граммы дают простой способ выучить полезные корни и суффиксы, не связываясь с этой вашей лингвистикой - только статистика, только хардкор.
#
# Например, слово `badass` мы можем представить в виде такой последовательности триграмм:
#
# `##b #ba bad ada das ass ss# s##`
#
# So interpretable, неправда ли?
#
# Реализовать это дело всё так же просто - нужно поставить `analyzer='char'` в вашем любимом Vectorizer'е и выбрать размер `ngram_range`.
#
# **Задание** Запилите классификатор на n-граммах символов и визуализируйте его.

# %% [markdown]
# ### to do Реализуем классификатор на n-граммах символов:
# * Test accuracy = 87.86% в исходном коде при ngram_range=(2, 6)
# * Test accuracy = 87.90% в случае ngram_range=(2, 5)

# %%
# исходный код
vectorizer = TfidfVectorizer(ngram_range=(2, 6), max_features=20000, analyzer='char')
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Test accuracy = 87.86%

# %%
# to do изменим range на (2, 5)
vectorizer = TfidfVectorizer(ngram_range=(2, 5), max_features=20000, analyzer='char')
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Test accuracy = 87.90%

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.954</b>, score <b>3.028</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
# ...

# %% [markdown]
# ## Подключаем лингвистику

# %% [markdown]
# ### Лемматизация и стемминг
#
# Если присмотреться, можно найти формы одного слова с разной семантической окраской по мнению классификатора. Или нет?
#
# **Задание** Найти формы слова с разной семантической окраской.
#
# Поверя, что они есть, попробуем что-нибудь с этим сделать.
#
# Например, лемматизируем - сведем к начальной форме все слова. Поможет в этом библиотека spacy.

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en', disable=['parser'])

docs = [doc for doc in nlp.pipe(train_df.review.values[:50])]

# %%
for token in docs[0]:
    print(token.text, token.lemma_)
# Out:
# Dreamgirls Dreamgirls
# , ,
# despite despite
# its -PRON-
# fistful fistful
# of of
# Tony Tony
# wins win
# in in
# an an
# incredibly incredibly
# weak weak
# year year
# on on
# Broadway Broadway
# , ,
# has have
# never never
# been be
# what what
# one one
# would would
# call call
# a a
# jewel jewel
# in in
# the the
# crown crown
# of of
# stage stage
# musicals musical
# . .
# However however
# , ,
# that that
# is be
# not not
# to to
# say say
# that that
# in in
# the the
# right right
# cinematic cinematic
# hands hand
# it -PRON-
# could could
# not not
# be be
# fleshed flesh
# out out
# and and
# polished polish
# into into
# something something
# worthwhile worthwhile
# on on
# - -
# screen screen
# . .
# Unfortunately unfortunately
# , ,
# what what
# transfers transfer
# to to
# the the
# screen screen
# is be
# basically basically
# a a
# slavishly slavishly
# faithful faithful
# version version
# of of
# the the
# stage stage
# hit hit
# with with
# all all
# ...

# %% [markdown]
# Весь этот процесс очень долгий, поэтому я предподсчитал всё.

# %%
import pickle

with open('train_docs.pkl', 'rb') as f:
    train_docs = pickle.load(f)
    
with open('test_docs.pkl', 'rb') as f:
    test_docs = pickle.load(f)

# %% [markdown]
# **Задание** Сделайте классификатор на лемматизированных текстах.

# %% [markdown]
# ### to do 2. Классифиактор на лемматизированных текстах (с помощью spacy)

# %%
# to do установим стоп-слова
from spacy.lang.en.stop_words import STOP_WORDS
stopwords = list(STOP_WORDS)
print(stopwords)
# Out:
# ['while', 'nevertheless', 'whereby', 'thus', 'together', 'whereafter', 'my', 'whole', 'everyone', 'further', 'mine', 'own', 'can', 'hers', 'must', 'before', 'they', 'noone', 'amount', '‘m', 'now', 'toward', 'then', 'whether', 'first', 'everything', 'therefore', 'these', '‘s', 'by', 'out', 'whence', 'never', 'the', 'amongst', 'although', 'anyhow', 'from', 'not', 'seem', 'why', 'using', 'until', 'rather', 'besides', 'none', 'moreover', 'front', 'latterly', '’ll', 'sometime', 'ten', 'hereafter', 'will', '’s', 'down', 'other', 'various', 'wherein', 'thereafter', 'alone', 'via', 'less', 'he', 'eight', 'part', 'serious', 'really', '’d', 'am', 'seeming', 'however', 'formerly', 'but', 'becoming', 'say', 'perhaps', 'those', 'four', 'over', "'d", 'his', 'themselves', 'just', 'into', 'former', 'no', 'and', 'do', 'ever', 'up', 'someone', 'whatever', 'under', 'move', 'empty', 'where', 'how', 'a', 'please', 'hundred', 'did', 'yourselves', 'whereas', 'through', 'ca', "'re", 'cannot', 'within', 'put
# ...

# %%
len(stopwords)
# Out:
# 326

# %%
# to do установим пунктуацию
import string
punct = string.punctuation

# %%
# to do функция для лемматизации и токенизации
def text_data_clearning(sentence):
  doc = nlp(sentence)

  tokens = []
  for token in doc:
    if token.lemma_ != "-PRON-":
      temp = token.lemma_.lower().strip()
    else:
      temp = token.lower_
    tokens.append(temp)
  
  cleaned_tokens = []
  for token in tokens:
    if token not in stopwords and token not in punct:
       cleaned_tokens.append(token)
  return cleaned_tokens

# %%
# to do проверяем работу функции на игрушечном примере
text_data_clearning("      Hello how are you. Like this video")
# Out:
# ['hello', 'like', 'video']

# %%
# to установка модулей
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression

# %%
def eval_model(model, test_df):
    preds = model.predict(test_df['review'])
    print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
    # print(" ")
    # print(classification_report(test_df['is_positive'], preds))
    # print (confusion_matrix(test_df['is_positive'], preds))

# %%
# %%time
# to do Векторизация TF-IDF + Модель на леммах
tfidf = TfidfVectorizer(tokenizer = text_data_clearning, ngram_range=(1, 2))
classifier = LogisticRegression()

model = Pipeline([('tfidf', tfidf), ('clf', classifier)])
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# CPU times: user 13min 23s, sys: 28.1 s, total: 13min 51s
# Wall time: 13min 27s

# %%
# %%time
eval_model(model, test_df)
# Out:
# Test accuracy = 87.24%
# CPU times: user 12min 23s, sys: 6.36 s, total: 12min 29s
# Wall time: 12min 30s

# %%
# %%time
# to do Векторизация TF-IDF + Модель на леммах
tfidf = TfidfVectorizer(tokenizer = text_data_clearning)
classifier = LinearSVC()

model = Pipeline([('tfidf', tfidf), ('clf', classifier)])
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# CPU times: user 11min 26s, sys: 5.37 s, total: 11min 31s
# Wall time: 11min 31s

# %%
# %%time
eval_model(model, test_df)
# Out:
# Test accuracy = 86.46%
# CPU times: user 10min 55s, sys: 4.92 s, total: 11min
# Wall time: 10min 59s

# %%
model.predict(['Wow, this is amazing lesson'])
# Out:
# array([1])

# %%
model.predict(['Wow, this sucks'])
# Out:
# array([0])

# %%
model.predict(['Worth of watching it. Please like it'])
# Out:
# array([1])

# %% [markdown]
# Более простой способ нормализации слов - использовать стемминг. Он немного тупой, не учитывает контекст, но иногда оказывается даже эффективнее лемматизации - а, главное, быстрее.
#
# По сути это просто набор правил, как обрезать слово, чтобы получить основу (stem):

# %%
from nltk import PorterStemmer

stemmer = PorterStemmer()

print(stemmer.stem('Become'))
print(stemmer.stem('becomes'))
print(stemmer.stem('became'))
# Out:
# becom
# becom
# becam

# %% [markdown]
# **Задание** Попробуйте вместо лемм классифицировать основы.

# %% [markdown]
# ### to do 3. Классификатор на основах (стемминг)
# В библиотеке Spacy не предусмотрен стемиинг, поэтому используем PorterStemmer

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# to do функции для токенизации и стемминга, препроцессинга
sw = stopwords.words('english')

def tokenizer_porter(text):
    tokens = [stemmer.stem(word) for word in text.split()]
    return [w for w in tokens if not w in sw]

def preprocessor(text):
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
    text = re.sub('[\W]+', ' ', text.lower()) +\
        ' '.join(emoticons).replace('-', '')
    return text

# %%
# to do проверяем работу функции на игрушечном примере
tokenizer_porter("      Hello how are you. Like this video")
# Out:
# ['hello', 'you.', 'like', 'thi', 'video']

# %%
# to do проверяем работу функции на игрушечном примере
preprocessor("      Hello how are you. Like this video")
# Out:
# ' hello how are you like this video'

# %%
# %%time
# to do Векторизация TF-IDF + Модель на основах
tfidf = TfidfVectorizer(preprocessor=preprocessor, 
                        tokenizer=tokenizer_porter, 
                        ngram_range=(1, 2))

classifier = LogisticRegression()

model = Pipeline([('tfidf', tfidf), ('clf', classifier)])
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# CPU times: user 3min 7s, sys: 11.9 s, total: 3min 19s
# Wall time: 3min 5s

# %%
# %%time
eval_model(model, test_df)
# Out:
# Test accuracy = 88.64%
# CPU times: user 2min 25s, sys: 336 ms, total: 2min 26s
# Wall time: 2min 26s

# %%
# %%time
# to do Векторизация TF-IDF + Модель на основах
tfidf = TfidfVectorizer(strip_accents=None,
                        lowercase=False, 
                        preprocessor=preprocessor, 
                        tokenizer=tokenizer_porter, 
                        use_idf=True, norm='l2',
                        smooth_idf=True)

classifier = LinearSVC()

model = Pipeline([('tfidf', tfidf), ('clf', classifier)])
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# CPU times: user 2min 15s, sys: 247 ms, total: 2min 15s
# Wall time: 2min 16s

# %%
# %%time
eval_model(model, test_df)
# Out:
# Test accuracy = 86.75%
# CPU times: user 2min 12s, sys: 230 ms, total: 2min 12s
# Wall time: 2min 12s

# %% [markdown]
# ### NER
#
# В текстах рецензий очень много именованных сущностей. Вот, например:

# %%
displacy.render(docs[0], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dreamgirls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , despite its fistful of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wins in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     an incredibly weak year
# ...

# %% [markdown]
# Вообще говоря, почему вдруг какой-нибудь Депп должен нести семантическую окраску? Однако оказывается, что классификатор выучивает, что какие-то имена чаще в положительных рецензиях - или наоборот. Это похоже на переобучение - почему бы не попробовать вырезать сущности?
#
# **Задание** Удалите из текстов какие-то из сущностей, пользуясь координатами из запикленных файлов. Описание сущностей можно посмотреть [здесь](https://spacy.io/api/annotation#named-entities). Запустите классификатор.

# %% [markdown]
# ### to do 4. Классификатор на тексте с вырезанными сущностями (с помощью spacy)

# %%
# to do Удалим некоторые именованные сущности в игрушечном примере
text_data = 'This is a text document that speaks about entities like New York and Nokia. \
My name is John Smith. I am working for UN since 20:00. \
My income is $100000 per year.'

doc = nlp(text_data)

# You can add other Named Entities types that you would want to remove to the list
text_without_ne = [token.text for token in doc if token.ent_type_ not in ['GPE', 'PERSON', 'ORG', 'TIME', 'MONEY']]

print(" ".join(text_without_ne))
# Out:
# This is a text document that speaks about entities like and . My name is . I am working for since . My income is $ per year .

# %%
# to do установим стоп-слова
from spacy.lang.en.stop_words import STOP_WORDS
stopwords = list(STOP_WORDS)
print(stopwords)
# Out:
# ['while', 'nevertheless', 'whereby', 'thus', 'together', 'whereafter', 'my', 'whole', 'everyone', 'further', 'mine', 'own', 'can', 'hers', 'must', 'before', 'they', 'noone', 'amount', '‘m', 'now', 'toward', 'then', 'whether', 'first', 'everything', 'therefore', 'these', '‘s', 'by', 'out', 'whence', 'never', 'the', 'amongst', 'although', 'anyhow', 'from', 'not', 'seem', 'why', 'using', 'until', 'rather', 'besides', 'none', 'moreover', 'front', 'latterly', '’ll', 'sometime', 'ten', 'hereafter', 'will', '’s', 'down', 'other', 'various', 'wherein', 'thereafter', 'alone', 'via', 'less', 'he', 'eight', 'part', 'serious', 'really', '’d', 'am', 'seeming', 'however', 'formerly', 'but', 'becoming', 'say', 'perhaps', 'those', 'four', 'over', "'d", 'his', 'themselves', 'just', 'into', 'former', 'no', 'and', 'do', 'ever', 'up', 'someone', 'whatever', 'under', 'move', 'empty', 'where', 'how', 'a', 'please', 'hundred', 'did', 'yourselves', 'whereas', 'through', 'ca', "'re", 'cannot', 'within', 'put
# ...

# %%
# to do функция для токенизации, лемматизации, удаления некоторых именованных сущностей
def text_data_clearning_ner(sentence):
  doc = nlp(sentence)

  tokens = []
  for token in doc:
    if token.ent_type_ not in ['GPE', 'PERSON', 'ORG', 'TIME', 'MONEY']:
      if token.lemma_ != "-PRON-":
        temp = token.lemma_.lower().strip()
      else:
        temp = token.lower_
      tokens.append(temp)
  
  cleaned_tokens = []
  for token in tokens:
    if token not in stopwords and token not in punct:
       cleaned_tokens.append(token)
  return cleaned_tokens

# %%
# to do проверяем работу функции на игрушечном примере
text_data_clearning_ner("      Hello how are you. Like this video. I am looking for it since 20:00.")
# Out:
# ['hello', 'like', 'video', 'look']

# %%
# %%time
# to do Векторизация TF-IDF + Модель на леммах с извлечением именованных сущностей
tfidf = TfidfVectorizer(tokenizer = text_data_clearning_ner,
                        ngram_range=(1, 2))
classifier = LogisticRegression()

model = Pipeline([('tfidf', tfidf), ('clf', classifier)])
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# CPU times: user 12min 27s, sys: 16.9 s, total: 12min 44s
# Wall time: 12min 31s

# %%
# %%time
eval_model(model, test_df)
# Out:
# Test accuracy = 87.42%
# CPU times: user 11min 58s, sys: 5.85 s, total: 12min 4s
# Wall time: 12min 3s

# %%
# %%time
# to do Векторизация TF-IDF + Модель на леммах с извлечением именованных сущностей
tfidf = TfidfVectorizer(tokenizer = text_data_clearning_ner)
classifier = LinearSVC()

model = Pipeline([('tfidf', tfidf), ('clf', classifier)])
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# CPU times: user 11min 29s, sys: 6.8 s, total: 11min 36s
# Wall time: 11min 36s

# %%
# %%time
eval_model(model, test_df)
# Out:
# Test accuracy = 87.02%
# CPU times: user 11min 4s, sys: 5.2 s, total: 11min 9s
# Wall time: 11min 8s

# %% [markdown]
# ### to do Результаты подключения лингвистики
# Стандартный подход включает векторайзер TfidfVectorizer при ngram_range=(1, 2) и классифиактор LogisticRegression()
# 1. Test accuracy = 88.64% на стандартных подходах без лемматизации или стимминга
# 2. Test accuracy = 87.24 на стандартных подходах с лемматизацией
# 3. Test accuracy = 88.64% на стандартных подходах со стиммингом
# 4. Test accuracy = 87.42% на стандартных подходах с лемматизацией и извлечением именованных сущностей
#
# На рассматриваемых данных:
# * На стандартных подходах без лемматизации качество выше.
# * Стемминг работает намного быстрее лемматизации и дает качество выше.
# * В случае добавления извлечения именованных сущностей к лемматизации качество немного повысилось.

# %% [markdown]
# ## Включаем дип лёрнинг

# %% [markdown]
# Мы тут пришли deep learning'ом заниматься, а делаем почему-то модель на логистической регрессии. Как так?
#
# Попробуем запустить относительно стандартную модель для классификации текстов - сверточная сеть поверх словных эмбеддингов.
#
# Разбираться, что это за зверь, будем на следующих занятиях, а пока будем просто им пользоваться :)
#
# Каждое предложение нужно представлять набором слов - и сразу же начинаются проблемы. Во-первых, как ограничить длину предложения?
#
# Прикинем по гистограмме, какая длина нам подходит:

# %%
train_df['review']
# Out:
# 0        Dreamgirls, despite its fistful of Tony wins in an incredibly weak year on Broadway, has never been what one would call a jewel in the crown of st...
# 1        This show comes up with interesting locations as fast as the travel channel. It is billed as reality but in actuality it is pure prime time soap o...
# 2        I simply love this movie. I also love the Ramones, so I am sorta biased to begin with in the first place. There isn't a lot of critical praise to ...
# 3        Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin,...
# 4        My all-time favorite movie! I have seen many movies, but this one beats them all! Excelent acting, wonderful story. You will, as a "normal" caring...
#                                                                                  ...
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

_, _, hist = plt.hist(train_df.review.apply(lambda text: len(text.split())), bins='auto')
hist
# Out:
# <a list of 230 Patch objects>

# %% [markdown]
# Кроме этого, нужно перенумеровать как-то слова.

# %%
from collections import Counter

words_counter = Counter((word for text in train_df.review for word in text.lower().split()))

word2idx = {
    '': 0,
    '<unk>': 1
}
for word, count in words_counter.most_common():
    if count < 10:
        break
        
    word2idx[word] = len(word2idx)
    
print('Words count', len(word2idx))
# Out:
# Words count 27299

# %% [markdown]
# **Задание** Сконвертируйте данные

# %%
import numpy as np

def convert(texts, word2idx, max_text_len):
    data = np.zeros((len(texts), max_text_len), dtype=np.int)
    
    for inx, text in enumerate(texts):
        result = []
        for word in text.split():
            if word in word2idx:
                result.append(word2idx[word])
        padding = [0]*(max_text_len - len(result))
        data[inx] = np.array(padding + result[-max_text_len:], dtype=np.int)
    return data

X_train = convert(train_df.review, word2idx, 1000)
X_test = convert(test_df.review, word2idx, 1000)

# %% [markdown]
# Поставим учиться модельку на keras.
#
# *Напоминание*: на keras, чтобы обучить модель, нужно
# 1. Определить модель, например:
# ```python
# model = Sequential()
# model.add(Dense(1, activation='sigmoid', input_dim=NUM_WORDS))
# ```
# 2. Задать функцию потерь и оптимизатор:
# ```python
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# ```
#
# 3. Запустить обучение:
# ```python
# model.fit(X_train, y_train,
#           batch_size=32,
#           epochs=3,
#           validation_data=(X_test, y_test))
# ```
#
# В NLP чаще всего ставятся задачи классификации, поэтому нужно запомнить такие функции потерь:
#
# *   **categorical_crossentropy** - для многоклассовой классификации, в качестве меток должны передаваться one-hot-encoding вектора
# *   **sparse_categorical_crossentropy** - аналогично предыдущему, но в качестве меток нужно передавать просто индексы соответствующих классов
# *   **binary_crossentropy** - для бинарной классификации
#
#
# В качестве оптимизатора обычно используют `sgd` или `adam`.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
# import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalMaxPooling1D, Dropout

# %%
model = Sequential([
    Embedding(input_dim=len(word2idx), output_dim=64, input_shape=(X_train.shape[1],)),
    GlobalMaxPooling1D(),
    Dense(units=10, activation='relu'),
    Dense(units=10, activation='relu'),
    Dense(units=1, activation='sigmoid')
])

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 1000, 64)          1747136
# _________________________________________________________________
# global_max_pooling1d (Global (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                650
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# ...
# Total params: 1,747,907
# Trainable params: 1,747,907
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, train_df.is_positive, batch_size=128, epochs=10, 
          validation_data=(X_test, test_df.is_positive))
# Out:
# Epoch 1/10
# 196/196 [==============================] - 12s 43ms/step - loss: 0.6182 - accuracy: 0.6486 - val_loss: 0.4338 - val_accuracy: 0.8396
# Epoch 2/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.3046 - accuracy: 0.8820 - val_loss: 0.3002 - val_accuracy: 0.8711
# Epoch 3/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.1781 - accuracy: 0.9362 - val_loss: 0.2996 - val_accuracy: 0.8736
# Epoch 4/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.0973 - accuracy: 0.9712 - val_loss: 0.3284 - val_accuracy: 0.8714
# Epoch 5/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.0461 - accuracy: 0.9902 - val_loss: 0.3722 - val_accuracy: 0.8667
# Epoch 6/10
# 196/196 [==============================] - 8s 43ms/step - loss: 0.0195 - accuracy: 0.9973 - val_loss: 0.4150 - val_accuracy: 0.8652
# Epoch 7/10
# ...

# %% [markdown]
# **Задание** Подсчитайте качество модели на тесте

# %%
  # to do оценка качества модели
  loss, accuracy = model.evaluate(X_test, test_df.is_positive)
  print("Test loss {:.4f}, accuracy {:.2f}%".format(loss, accuracy * 100))
# Out:
# 782/782 [==============================] - 3s 4ms/step - loss: 0.5136 - accuracy: 0.8628
# Test loss 0.5136, accuracy 86.28%

# %% [markdown]
# ## to do Вывод
#
# 1. Наилучшее качество получено на классификаторе со стеммингом и ngram_range = (1, 2).
#
# 2. Нейронная сеть переобучилась, начиная с третьей эпохи. Качество, полученное на нейронной сети, посредине между классификатором с лемматизацией и классифиактором со стеммингом.
#
# 3. Классификаторы с лемматизацией работали очень медленно и неэффективно.
